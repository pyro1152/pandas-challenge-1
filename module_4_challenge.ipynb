# %% [markdown]
# ## Part 1: Explore the Data
#
# Import the data and use Pandas to learn more about the dataset.

# %%
import pandas as pd

df = pd.read_csv('Resources/client_dataset.csv')

df.head()
# Out:
#        first      last                    job               phone  \
# 0     Donald   Harding           Immunologist  793-904-7725x39308
# 1    Tiffany     Myers        Music therapist    201.442.4543x942
# 2    Shannon    Watson           Immunologist   687.737.9424x8503
# 3     Nathan     Baker  Accounting technician    827-788-8123x012
# 4  Christina  Schwartz           Chiropractor        265-829-3643
#
#                                  email  client_id  order_id  order_date  \
# 0     harding.donald.7185@sullivan.com      58515   8953482  2023-04-28
# 1    myers.t.6537@ferguson-johnson.net      37609   8069089  2023-05-19
# 2                swatson8146@payne.net      57113   1902144  2023-01-29
# 3               bakernathan@benson.com      46554   9031802  2023-04-25
# 4  christinaschwartz9252@mcconnell.com      92089   1322274  2023-05-28
#
#    order_week  order_year         item_id     category         subcategory  \
# ...

# %%
df.columns
# Out:
# Index(['first', 'last', 'job', 'phone', 'email', 'client_id', 'order_id',
#        'order_date', 'order_week', 'order_year', 'item_id', 'category',
#        'subcategory', 'unit_price', 'unit_cost', 'unit_weight', 'qty',
#        'line_number'],
#       dtype='object')

# %%
df.describe()
# Use the describe function to gather some basic statistics
# Out:
#           client_id      order_id    order_week    order_year    unit_price  \
# count  54639.000000  5.463900e+04  54639.000000  54639.000000  54639.000000
# mean   54837.869416  5.470190e+06     11.359139   2022.993064    136.267207
# std    25487.438231  2.599807e+06      7.023499      0.082997    183.873135
# min    10033.000000  1.000886e+06      1.000000   2022.000000      0.010000
# 25%    33593.000000  3.196372e+06      6.000000   2023.000000     20.800000
# 50%    53305.000000  5.496966e+06     11.000000   2023.000000     68.310000
# 75%    78498.000000  7.733869e+06     17.000000   2023.000000    173.160000
# max    99984.000000  9.998480e+06     52.000000   2023.000000   1396.230000
#
#           unit_cost   unit_weight           qty   line_number
# count  54639.000000  54639.000000  5.463900e+04  54639.000000
# mean      99.446073      5.004116  5.702646e+02      2.979667
# std      133.164267      5.326599  1.879552e+04      2.436320
# ...

# %%
# Use this space to do any additional research
# and familiarize yourself with the data.

# %%
# What three item categories had the most entries?
df['category'].value_counts().head(3)
# Out:
# category
# consumables    23538
# furniture      11915
# software        8400
# Name: count, dtype: int64

# %%
# For the category with the most entries, which subcategory had the most entries? 
most_common_category = df['category'].value_counts().idxmax()
most_common_category_only = df.loc[df['category'] == most_common_category]
most_common_subcategory_within_MCC = df['subcategory'].value_counts().idxmax()
most_common_subcategory_within_MCC_only = df.loc[df['subcategory'] == most_common_subcategory_within_MCC]

# %%
# Which five clients had the most entries in the data?
most_common_subcategory_within_MCC_only.head()
# Out:
#       first      last                             job               phone  \
# 21  Patrick  Anderson  Commercial art gallery manager  947-812-9604x27025
# 29    Caleb      Rice                Technical brewer    868.703.3751x760
# 45   Daniel    Newman      Designer, interior/spatial        907-222-8932
# 52    Jared    Taylor                   Haematologist        729-249-1032
# 71   Thomas     Ellis                   Haematologist   859-645-6362x6697
#
#                                   email  client_id  order_id  order_date  \
# 21  andersonboard7205@delgado-hodge.org      51869   5020751  2023-03-16
# 29                 riceelse@collins.com      10643   1940019  2023-03-03
# 45         newman.daniel.3570@patel.com      45569   8286486  2023-03-12
# 52                   taylorj@romero.com      37715   6174735  2023-01-07
# 71              ellis.t.2291@benson.net      55398   8766547  2023-02-11
#
#     order_week  order_year         item_id     category        subcategory  \
# ...

# %%
# Store the client ids of those top 5 clients in a list.
top_5 = most_common_subcategory_within_MCC_only.head()
client_IDs = top_5.index.tolist()
client_ids_list = list(client_IDs)

# %%
# How many total units (the qty column) did the
# client with the most entries order order?
client_with_most_entries = df['client_id'].value_counts().idxmax()
client_with_most_entries_only = df.loc[df['client_id'] == client_with_most_entries]
total_units_ordered = client_with_most_entries_only['qty'].sum()

print("Total units ordered by the client with the most entries:", total_units_ordered)
# Out:
# Total units ordered by the client with the most entries: 64313

# %% [markdown]
# ## Part 2: Transform the Data
# Do we know that this client spent the more money than client 66037? If not, how would we find out? Transform the data using the steps below to prepare it for analysis.

# %%
# Create a column that calculates the subtotal for each lqqine using the unit_price
# and the qty
df['subtotal'] = (df['unit_price'])* df['qty']

# %%
# Create a column for shipping price.
# Assume a shipping price of $7 per pound
# for orders over 50 pounds and $10 per
# pound for items 50 pounds or under.
df['shipping_price'] = (df['unit_weight'].apply(lambda x: 7 if x > 50 else 10))*df['qty']
df['Revenue'] =  (df['subtotal'])*1.095 + df['shipping_price']

# %%
# Create a column for the total price
# using the subtotal and the shipping price
# along with a sales tax of 9.25%
tax_rate= .0925
df['Revenue'] = df['subtotal'] + df['shipping_price']
df
# Out:
#            first       last                      job               phone  \
# 0         Donald    Harding             Immunologist  793-904-7725x39308
# 1        Tiffany      Myers          Music therapist    201.442.4543x942
# 2        Shannon     Watson             Immunologist   687.737.9424x8503
# 3         Nathan      Baker    Accounting technician    827-788-8123x012
# 4      Christina   Schwartz             Chiropractor        265-829-3643
# ...          ...        ...                      ...                 ...
# 54634     Lauren      Reese           Radio producer  977.877.5272x11382
# 54635    Derrick      Moore                 Musician        358.661.5483
# 54636     Monica  Gutierrez         Graphic designer    294.805.9100x339
# 54637      Wanda    Solomon             Toxicologist       (311)767-4924
# 54638     Dwayne       Bell  Chief Financial Officer   606-619-7667x9508
#
#                                      email  client_id  order_id  order_date  \
# ...

# %%
# Create a column for the cost
# of each line using unit cost, qty, and
# shipping price (assume the shipping cost
# is exactly what is charged to the client).
df['order_cost'] = (df['unit_cost'] ) * df['qty'] + df['shipping_price']

# %%
# Create a column for the profit of
# each line using line cost and line price
df['Total Profit'] = df['Revenue'] - df['order_cost']

df
# Out:
#            first       last                      job               phone  \
# 0         Donald    Harding             Immunologist  793-904-7725x39308
# 1        Tiffany      Myers          Music therapist    201.442.4543x942
# 2        Shannon     Watson             Immunologist   687.737.9424x8503
# 3         Nathan      Baker    Accounting technician    827-788-8123x012
# 4      Christina   Schwartz             Chiropractor        265-829-3643
# ...          ...        ...                      ...                 ...
# 54634     Lauren      Reese           Radio producer  977.877.5272x11382
# 54635    Derrick      Moore                 Musician        358.661.5483
# 54636     Monica  Gutierrez         Graphic designer    294.805.9100x339
# 54637      Wanda    Solomon             Toxicologist       (311)767-4924
# 54638     Dwayne       Bell  Chief Financial Officer   606-619-7667x9508
#
#                                      email  client_id  order_id  order_date  \
# ...

# %% [markdown]
# ## Part 3: Confirm your work
# You have email receipts showing that the total prices for 3 orders. Confirm that your calculations match the receipts. Remember, each order has multiple lines.
#
# Order ID 2742071 had a total price of \$152,811.89
#
# Order ID 2173913 had a total price of \$162,388.71
#
# Order ID 6128929 had a total price of \$923,441.25

# %%
order_2742071 = df[df['order_id'] == 2742071]
order_2173913 = df[df['order_id'] == 2173913]
order_6128929 = df[df['order_id'] == 6128929]

order_2742071_total = order_2742071['Revenue'].sum()
order_2173913_total = order_2173913['Revenue'].sum()
order_6128929_total = order_6128929['Revenue'].sum()

print(order_2742071_total)
print(order_2173913_total)
print(order_6128929_total)
# Out:
# 132189.33
# 121650.76
# 734504.2699999999

# %% [markdown]
# ## Part 4: Summarize and Analyze
# Use the new columns with confirmed values to find the following information.

# %%
# How much did each of the top 5 clients by quantity
# spend? Check your work from Part 1 for client ids.
df_sorted = df.sort_values(by='qty', ascending=False)
top_5_clients= df_sorted.head(5)
spending_amounts = top_5_clients.values
top_5_clients[['client_id','qty', 'Revenue' ]]
# Out:
#        client_id      qty       Revenue
# 21801      78965  3958244  6.240567e+08
# 25972      86721   977121  1.078742e+08
# 8761       30143   842581  2.944821e+07
# 15112      85931   637318  2.124946e+08
# 50048      77354   494692  4.513075e+07

# %%
# Create a summary DataFrame showing the totals for the
# for the top 5 clients with the following information:
# total units purchased, total shipping price,
# total revenue, and total profit. Sort by total profit.
Summary_df = top_5_clients[['client_id','qty', 'shipping_price', 'Revenue', 'Total Profit']]
Summary_df_sorted = Summary_df.sort_values('Total Profit', ascending=False)
Summary_df_sorted
# Out:
#        client_id      qty  shipping_price       Revenue  Total Profit
# 21801      78965  3958244        39582440  6.240567e+08  1.882145e+08
# 15112      85931   637318         6373180  2.124946e+08  8.895685e+07
# 25972      86721   977121         9771210  1.078742e+08  2.672426e+07
# 8761       30143   842581         8425810  2.944821e+07  8.307849e+06
# 50048      77354   494692         4946920  4.513075e+07  5.941251e+06

# %%
# Format the data and rename the columns
Summary_df_sorted_renamed = Summary_df_sorted.rename(columns={'client_id': 'Client ID', 'qty': 'Units', 'shipping_price': 'Shipping Costs','Revenue': 'Revenue','Total Profit': 'Total Profit'})

Summary_df_sorted_renamed['Shipping Costs'] = Summary_df_sorted_renamed['Shipping Costs'].apply(lambda x: "${:,.2f}M".format(x / 1000000))
Summary_df_sorted_renamed['Revenue'] = Summary_df_sorted_renamed['Revenue'].apply(lambda x: "${:,.2f}M".format(x / 1000000))
Summary_df_sorted_renamed['Total Profit'] = Summary_df_sorted_renamed['Total Profit'].apply(lambda x: "${:,.2f}M".format(x / 1000000))
Summary_df_sorted_renamed



# to names suitable for presentation.
# Currency should be in millions of dollars.
# Out:
#        Client ID    Units Shipping Costs   Revenue Total Profit
# 21801      78965  3958244        $39.58M  $624.06M     $188.21M
# 15112      85931   637318         $6.37M  $212.49M      $88.96M
# 25972      86721   977121         $9.77M  $107.87M      $26.72M
# 8761       30143   842581         $8.43M   $29.45M       $8.31M
# 50048      77354   494692         $4.95M   $45.13M       $5.94M

# %%
# Sort the updated data by "Total Profit" form highest to lowest

Summary_df_final = Summary_df_sorted_renamed.sort_values(by='Total Profit',ascending=False )
Summary_df_final['Total Profit'] = Summary_df_final['Total Profit'].apply(lambda x: "${:,.2f}M".format(x / 1))
Summary_df_final
# Out:
#        Client ID    Units Shipping Costs   Revenue Total Profit
# 21801      78965  3958244        $39.58M  $624.06M     $188.21M
# 15112      85931   637318         $6.37M  $212.49M      $88.96M
# 25972      86721   977121         $9.77M  $107.87M      $26.72M
# 8761       30143   842581         $8.43M   $29.45M       $8.31M
# 50048      77354   494692         $4.95M   $45.13M       $5.94M
